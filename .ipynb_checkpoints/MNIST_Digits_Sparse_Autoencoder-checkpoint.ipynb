# %%
import os

# Check if the current directory ends with 'data'
if os.getcwd()[-4:] != 'data':
    # Create the 'data' directory if it doesn't exist
    if not os.path.exists('data'):
        os.mkdir('data')

# %%
import os
print(os.getcwd())
# Out:
# D:\python notebooks

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import numpy as np
# Load and preprocess MNIST data
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

mnist_train = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_test = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = DataLoader(mnist_train, batch_size=64, shuffle=True)
test_loader = DataLoader(mnist_test, batch_size=64, shuffle=False)

class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3)
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.conv3 = nn.Conv2d(64, 64, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(576, 64)
        self.fc2 = nn.Linear(64, 10)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = torch.relu(self.conv3(x))
        x = torch.flatten(x, 1)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

mnist_train = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
mnist_test = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = DataLoader(mnist_train, batch_size=128, shuffle=True)
test_loader = DataLoader(mnist_test, batch_size=128, shuffle=False)

file_path_cnn = 'data/cnn_model.pth'
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

cnn_model = CNNModel().to(DEVICE)

if os.path.exists(file_path_cnn):
    cnn_model.load_state_dict(torch.load(file_path_cnn))
else:
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(cnn_model.parameters())

    num_epochs = 20
    cnn_model.to(DEVICE)

    for epoch in range(num_epochs):
        cnn_model.train()
        running_loss = 0.0
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(DEVICE), target.to(DEVICE)

            # Forward pass
            outputs = cnn_model(data)
            loss = criterion(outputs, target)

            # Backward pass and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            if (batch_idx + 1) % 100 == 0:
                print(f'Epoch [{epoch+1}/{num_epochs}], Step [{batch_idx+1}/{len(train_loader)}], '
                    f'Loss: {running_loss/100:.4f}')
                running_loss = 0.0

        # Validation
        cnn_model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(DEVICE), target.to(DEVICE)
                outputs = cnn_model(data)
                _, predicted = torch.max(outputs.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()

        print(f'Epoch [{epoch+1}/{num_epochs}], '
            f'Validation Accuracy: {100 * correct / total:.2f}%')
        
    torch.save(cnn_model.state_dict(), file_path_cnn)
# Out:
# C:\Users\Comp\AppData\Local\Temp\ipykernel_22920\3011054155.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   cnn_model.load_state_dict(torch.load(file_path_cnn))

# %%
def once(func):
    def wrapped(*args, **kwargs):
        if not wrapped.called:
            result = func(*args, **kwargs)
            wrapped.called = True
            return result
        
        if args[0] == 'reset':
            wrapped.called = False
    wrapped.called = False
    return wrapped

# %%
print_once = once(print)

# %%
# Function to get activations of the last layer
def get_activations(model, loader, output_device, compute_labels=False):
    model.eval()
    activations = []
    labels = []
    with torch.no_grad():
        for data, targets in loader:
            output = model(data.to(DEVICE))
            activations.append(output.to(output_device))
            if compute_labels:
                labels.append(targets)
    if compute_labels:
        return torch.cat(activations), torch.cat(labels)
    else:
        return torch.cat(activations)

# %%
reference_train_loader = DataLoader(mnist_train, batch_size=128, shuffle=False)
reference_train_activations, reference_labels = get_activations(cnn_model, reference_train_loader, output_device=DEVICE, compute_labels=True)

# %%
mnist_by_digit_lists = [[] for _ in range(10)]

# Iterate over the dataset and append images to the corresponding list
for image, label in mnist_train:
    mnist_by_digit_lists[label].append(image)

# %%
# Get activations from the CNN model
train_activations = get_activations(cnn_model, train_loader, output_device='cpu')
test_activations = get_activations(cnn_model, test_loader, output_device='cpu')

# Create datasets and dataloaders for the activations
train_dataset_SAE = TensorDataset(torch.FloatTensor(train_activations))
test_dataset_SAE = TensorDataset(torch.FloatTensor(test_activations))
train_loader_SAE = DataLoader(train_dataset_SAE, batch_size=128, shuffle=True)
test_loader_SAE = DataLoader(test_dataset_SAE, batch_size=128, shuffle=False)

# %%
# Define the Sparse Autoencoder
class SparseAutoencoder(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(SparseAutoencoder, self).__init__()
        self.encoder = nn.Linear(input_size, hidden_size)
        self.decoder = nn.Linear(hidden_size, input_size)

    def forward(self, x):
        encoded = torch.relu(self.encoder(x))
        decoded = torch.sigmoid(self.decoder(encoded))
        return encoded, decoded

# Hyperparameters
input_size = 10  # Size of the last layer of CNN (10 for MNIST)
hidden_size = 20
learning_rate = 1e-3
num_epochs = 50
sparsity_weight = 1e-5

file_path_sae = 'data/sparse_autoencoder_mnist.pth'

if os.path.exists(file_path_sae):
    sae = SparseAutoencoder(input_size, hidden_size).to(DEVICE)
    sae.load_state_dict(torch.load(file_path_sae))
else: 
    sae = SparseAutoencoder(input_size, hidden_size).to(DEVICE)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(sae.parameters(), lr=learning_rate)

    # Training loop
    for epoch in range(num_epochs):
        sae.train()
        total_loss, total_reconstruction_loss, total_weighted_sparcity_loss = 0, 0, 0

        for data in train_loader_SAE:
            inputs = data[0].to(DEVICE)

            # Forward pass
            encoded, decoded = sae(inputs)

            # Compute loss
            reconstruction_loss = criterion(decoded, inputs)
            sparsity_loss = torch.sum(torch.abs(encoded))
            loss = reconstruction_loss + sparsity_weight * sparsity_loss

            # Backward pass and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_reconstruction_loss += reconstruction_loss.item()
            total_weighted_sparcity_loss += (sparsity_weight * sparsity_loss).item()
            total_loss += loss.item()

        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {total_loss/len(train_loader_SAE):.4f}')
        print(f'Reconstruction loss: {reconstruction_loss/len(train_loader_SAE):.4f}')
        print(f'Weighted sparcity loss: {total_weighted_sparcity_loss/len(train_loader_SAE):.4f}')
        

    # Save the model
    torch.save(sae.state_dict(), file_path_sae)

sae.eval()
# Out:
# C:\Users\Comp\AppData\Local\Temp\ipykernel_13844\2681143812.py:24: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   sae.load_state_dict(torch.load(file_path_sae))
# SparseAutoencoder(
#   (encoder): Linear(in_features=10, out_features=20, bias=True)
#   (decoder): Linear(in_features=20, out_features=10, bias=True)
# )

# %%
import matplotlib.pyplot as plt

# what example to visualize
number = np.random.randint(len(reference_train_activations))

with torch.no_grad():
    reconstructed_cnn_activations = sae(reference_train_activations[number])[-1].detach()
    cnn_activations = reference_train_activations[number].cpu()
    print(cnn_activations)
    reconstructed_cnn_activations = reconstructed_cnn_activations.cpu()

print(f"prediction = {torch.argmax(cnn_activations).item()}")
print(f"prediction according to reconstructed activations = {torch.argmax(reconstructed_cnn_activations).item()}")
print(f"actual label = {reference_labels[number]}")
# Ensure that both activations are on a similar scale if necessary
# If the values differ significantly, you might want to normalize them.

# Bar Chart
plt.figure(figsize=(10, 4))


# Set up the positions and bar width
bar_width = 0.4
indices = np.arange(10)

# Plot the original cnn activations
plt.bar(indices, cnn_activations, width=bar_width, color='darkmagenta', alpha=0.7, label='Original Activations')

# Plot the reconstructed cnn activations with an offset and transparency
plt.bar(indices+bar_width, reconstructed_cnn_activations, width=bar_width, color='pink', alpha=0.7, label='Reconstructed Activations')

plt.xticks(indices+bar_width/2, labels=indices)

plt.grid(True, which='both', linestyle='-', linewidth=0.5, alpha=0.5, axis='y')

# Adding labels, title, and legend
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Comparison')
plt.legend()

# Adjust layout to prevent clipping
plt.tight_layout()
plt.show()
# Out:
# tensor([-12.4094, -13.4662,  -7.8622,   2.5436, -15.5937,  -8.0997, -14.0060,
#         -24.7809,  23.4736,   0.7421])
# prediction = 8
# prediction according to reconstructed activations = 8
# actual label = 8

# %%
both, only_cnn, only_rec, neither = ([] for i in range(4))

with torch.no_grad():
  for i in range(len(reference_train_activations)):
    cnn_activations, y = reference_train_activations[i], reference_labels[i]

    reconstructed_cnn_activations = sae(cnn_activations)[-1].detach().cpu()

    prediction = torch.argmax(cnn_activations).item()
    rec_prediction = torch.argmax(reconstructed_cnn_activations).item()

    # print(f"activations = {cnn_activations}")
    # print(f"y = {y}")
    # print(f"prediction = {prediction}")

    if prediction == y:
      if rec_prediction == y:
        both.append(i)
      else:
        only_cnn.append(i)
    else:
      if rec_prediction == y:
        only_rec.append(i)
      else:
        neither.append(i)

# %%
# cases where both the prediction from cnn and the reconstruction are correct
print(len(both))
# Out:
# 51365

# %%
# cases where only the prediction is correct
print(len(only_cnn))
# Out:
# 8556

# %%
# cases where the prediction from cnn is incorrect but the reconstruction correctly classifies the digit
print(len(only_rec))
# Out:
# 24

# %%
# cases where both are wrong
print(len(neither))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # cases where both are wrong
# ----> 2 print(len(neither))
#
# NameError: name 'neither' is not defined

# %%
print(reference_train_activations[0])
# Out:
# tensor([-18.0225,  -9.8141, -34.3493,  10.0203, -28.7933,  24.0919, -14.4446,
#         -23.1498, -10.0285,  -1.8420], device='cuda:0')

# %%
example = np.random.randint(len(reference_train_activations))
with torch.no_grad():
    sparse_representation = sae(reference_train_activations[example].to(DEVICE))[0].detach().cpu() # activations of the middle layer of the SAE
print(sparse_representation)

plt.figure(figsize=(10, 4))

# Set up the positions and bar width
bar_width = 0.4
indices = np.arange(hidden_size)



# Plot the original cnn activations
plt.bar(indices, sparse_representation, width=bar_width, color='darkmagenta', alpha=0.7, label='Values')

# Plot the reconstructed cnn activations with an offset and transparency

plt.xticks(indices, labels=indices)

plt.grid(True, which='both', linestyle='-', linewidth=0.5, alpha=0.5, axis='y')

# Adding labels, title, and legend
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Sparse representation')


# Adjust layout to prevent clipping
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 example = np.random.randint(len(reference_train_activations))
#       2 with torch.no_grad():
#       3     sparse_representation = sae(reference_train_activations[example].to(DEVICE))[0].detach().cpu() # activations of the middle layer of the SAE
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:1187, in _pydevd_bundle.pydevd_cython_win32_312_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:627, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:937, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:928, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython_win32_312_64.pyx:585, in _pydevd_bundle.pydevd_cython_win32_312_64.PyDBFrame.do_wait_suspend()
#
# File D:\PyCharm 2024.2\plugins\python-ce\helpers\pydev\pydevd.py:1207, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1204         from_this_thread.append(frame_id)
#    1206 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1207     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File D:\PyCharm 2024.2\plugins\python-ce\helpers\pydev\pydevd.py:1222, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1219             self._call_mpl_hook()
#    1221         self.process_internal_commands()
# -> 1222         time.sleep(0.01)
#    1224 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1226 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
max_activations_list = [[] for i in range(hidden_size)]

# %%
with torch.no_grad():
  for i in range(len(reference_train_activations)):
    sparse_representation = sae(reference_train_activations[i].to(DEVICE))[0] # activations of the middle layer of the SAE
    max_activations_list[torch.argmax(sparse_representation)].append(i)

# %%
for l in max_activations_list:
  print(f"Was the neuron with max activation for {len(l)} examples.")
# Out:
# Was the neuron with max activation for 5965 examples.
# Was the neuron with max activation for 0 examples.
# Was the neuron with max activation for 0 examples.
# Was the neuron with max activation for 6216 examples.
# Was the neuron with max activation for 7 examples.
# Was the neuron with max activation for 0 examples.
# Was the neuron with max activation for 0 examples.
# Was the neuron with max activation for 0 examples.
# Was the neuron with max activation for 1 examples.
# Was the neuron with max activation for 5538 examples.
# Was the neuron with max activation for 5923 examples.
# Was the neuron with max activation for 5902 examples.
# Was the neuron with max activation for 6297 examples.
# Was the neuron with max activation for 6733 examples.
# Was the neuron with max activation for 6794 examples.
# Was the neuron with max activation for 0 examples.
# Was the neuron with max activation for 4759 examples.
# Was the neuron with max activation for 0 examples.
# Was the neuron with max activation for 5865 examples.
# Was the neuron with max activation for 0 examples.

# %%
import math
def visualize(nums, dataset=mnist_train):

    figure = plt.figure(figsize=(8, 8))
    side_length = math.ceil(math.sqrt(len(nums)))
    for i in range(len(nums)):
        img = mnist_train[nums[i]][0].squeeze()
        label = mnist_train[nums[i]][1]
        figure.add_subplot(side_length, side_length, i+1)
        plt.axis("off")
        plt.imshow(img.squeeze(), cmap="gray")
    plt.show()

# %%
visualize(max_activations_list[0][:225])

# %%
def store_activations(model):
    def storing_activations_hook(model, input, output):
        model.stored_activations = output

    model.stored_activations = None
    model.register_forward_hook(storing_activations_hook)

    return storing_activations_hook


def store_inputs(model):
    def storing_input_activations_hook(model, input, output):   
        if len(input) != 1: 
            print("woa woa woa")

        model.stored_inputs = input[0] # this is because input passed to this function by pytorch is a tuple (in our case, with only one element)
    
    model.stored_inputs = None
    model.register_forward_hook(storing_input_activations_hook)

    return storing_input_activations_hook

# %%
# Out:
# <bound method Module.children of Sequential(
#   (0): Linear(in_features=10, out_features=20, bias=True)
#   (1): Linear(in_features=20, out_features=10, bias=True)
# )>

# %%
encoded_hook_handle = store_inputs(sae.decoder) # the input to the decoder is the encoded input

# %%
inputs_hook_handle = store_inputs(sae.encoder) # the input to the sae

# %%
fc2_output_hook_handle = store_activations(cnn_model.fc2)

# %%
hooks_dict = {}
for name, module in cnn_model.named_children():
    hooks_dict[name] = store_activations(module)

# %%
hooks_dict.keys()
# Out:
# dict_keys(['conv1', 'conv2', 'conv3', 'pool', 'fc1', 'fc2'])

# %%
# Out:
# 32

# %%
for name, module in cnn_model.named_children():
    print(f"{name}.stored_activations = {module.stored_activations}")

# %%
def print_registered_forward_hooks(model, model_name=None):
    
    if model_name is None:
        if hasattr(model, 'name'):
            model_name = model.name
        else:
            model_name = model.__class__.__name__
    
    print(f"Registered forward hooks of {model_name}:")
    for module in model.children():
        hooks = module._forward_hooks
        if hooks:
            for hook_id, hook in hooks.items():
                print(f"Module: {module}, Hook ID: {hook_id}, Hook: {hook.__qualname__}")

print_registered_forward_hooks(sae)
print_registered_forward_hooks(cnn_model)
# Out:
# Registered forward hooks of SparseAutoencoder:
# Module: Linear(in_features=20, out_features=10, bias=True), Hook ID: 0, Hook: store_inputs.<locals>.storing_input_activations_hook
# Registered forward hooks of CNNModel:
# Module: Linear(in_features=64, out_features=10, bias=True), Hook ID: 1, Hook: store_activations.<locals>.storing_activations_hook

# %%
# function for removing all hooks
from typing import Dict, Callable
from collections import OrderedDict

def remove_all_forward_hooks(model: torch.nn.Module) -> None:
    for child in model.children():
        if child is not None:
            if hasattr(child, "_forward_hooks"):
                child._forward_hooks: Dict[int, Callable] = OrderedDict() # type: ignore
            remove_all_forward_hooks(child)

# %%
remove_all_forward_hooks(sae)

# %%
# remove_all_forward_hooks(cnn_model)

# %%
def visualize_ims(images, channel, text=None):
    
    images = images.detach()

    figure = plt.figure(figsize=(8, 8))

    side_length = side_length = math.ceil(math.sqrt(len(images)))

    for i in range(len(images)):
        img = images[i, channel].cpu()
        figure.add_subplot(side_length, side_length, i+1)
        plt.axis("off")
        plt.imshow(img.squeeze(), cmap="gray")
    if text:
        plt.title(text)
    plt.show()

# %%
print_once('reset')
# Out:
# reset

# %%
sae(reference_train_activations[0])
# Out:
# (tensor([0.0000, 0.0000, 0.0000, 3.5333, 0.9211, 0.0000, 0.0000, 0.0000, 0.0000,
#          8.5666, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1277, 0.0000,
#          0.0000, 0.0000], device='cuda:0', grad_fn=<ReluBackward0>),
#  tensor([7.1250e-06, 8.4299e-06, 6.9054e-07, 1.0000e+00, 3.6151e-07, 1.0000e+00,
#          1.6421e-05, 1.3880e-06, 1.9866e-05, 2.6667e-04], device='cuda:0',
#         grad_fn=<SigmoidBackward0>))

# %%
sae.decoder.stored_inputs

# %%
print(cnn_model.fc2.stored_activations)
# Out:
# None

# %%
sample = torch.stack([mnist_by_digit_lists[i][0] for i in range(10)])

# %%
# Function to optimize image for a specific neuron
from IPython.display import clear_output
from torchvision.transforms import functional as TF


def optim_inputs_for_neurons_in_layer(model, layer, mode='activations', neuron_indices=None, im_init='random', alpha=20.0, image_sparsity=50.0, num_steps=1000, device=DEVICE):
    model_on_device = model.to(device)
    layer_on_device = layer.to(device)
    neuron_indices = neuron_indices.to(device)
    # if neuron_indices is None:
    #     neuron_indices = torch.arange(layer_on_device.shape[-1]) # fix this, should be -2 

    if im_init == 'random':
        optimized_images = torch.randn((len(neuron_indices), 1, 28, 28), device=device, requires_grad=True) # TODO: improve initialization
    elif im_init == 'mnist':
        optimized_images = next(iter(reference_train_loader))[0][:len(neuron_indices)].to(device)
        optimized_images.requires_grad_(True)
    else:
        optimized_images = sample.to(device)
        optimized_images.requires_grad_(True)

    # visualize_ims(optimized_images, channel=0)

    optimizer = optim.Adam([optimized_images], lr=1e-3)

    def get_activations():
        if mode == 'activations':
            return layer_on_device.stored_activations
        elif mode == 'inputs':
            return layer_on_device.stored_inputs
        else:
            raise ValueError("Mode must be 'activations' or 'inputs'")

    rotation_angles = [5, 10, 15]

    activations_to_optimize_for = get_activations()
    print(f"Initial activations: {get_activations()}")

    if max(neuron_indices) > activations_to_optimize_for.shape[-1]:
        print("neuron_indices out of range.")

    # Optimization loop
    print_once('reset')
    for step in range(num_steps):

        optimizer.zero_grad()

        model_on_device(optimized_images)

        # Dynamically fetch inputs or activations from the layer based on the mode
        activations_to_optimize_for = get_activations()

        #create a batch of activations 
        batch_of_activations = activations_to_optimize_for[:len(neuron_indices)]

        target_neurons_activations = torch.sum(batch_of_activations[torch.arange(len(neuron_indices)), neuron_indices])
        original_loss = torch.sum(batch_of_activations) - alpha * target_neurons_activations

        # print_once(f"""
        #            batch_of_activations.shape = {batch_of_activations.shape}
        #            neuron_indices.shape = {neuron_indices.shape}
        #            torch.arange(len(neuron_indices).shape = {torch.arange(len(neuron_indices)).shape}
        #            origingal_loss = {original_loss}""")

        total_loss = original_loss + image_sparsity * torch.sum(optimized_images)

        for angle in rotation_angles:
            rotated_images = TF.rotate(optimized_images, angle)
            model_on_device(rotated_images)
            rotated_activations = get_activations()
            batch_of_rotated_activations = rotated_activations[:len(neuron_indices)]
            # Calculate rotation loss
            target_neurons_activations = torch.sum(batch_of_rotated_activations[torch.arange(len(neuron_indices)), neuron_indices])
            rotation_loss = torch.sum(batch_of_rotated_activations) - alpha * target_neurons_activations
            total_loss += rotation_loss + image_sparsity * torch.sum(rotated_images)

        total_loss.backward()

        optimizer.step()

        # if (step + 1) % 1000 == 0:
        #     plt.close('all')
        #     clear_output(wait=True)
        #     print(f"step#{step + 1}")
        #     print(f"Original loss: {original_loss.item()}, Rotation loss: {rotation_loss.item()}, Sparsity loss: {image_sparsity * torch.sum(optimized_images).item()}")
        #     visualize_ims(optimized_images, channel=0)
        #     print(f"Activations: {get_activations()}")
        

    return optimized_images.detach()

# %%
# # Optimize images for all neurons in the target layer
# optimized_images = optim_inputs_for_neurons_in_layer(nn.Sequential(cnn_model, sae), activations_to_optimize=sae.decoder.stored_inputs, neuron_indices=torch.arange(20), num_steps=100000)

# torch.set_printoptions(precision=4, sci_mode=False)
# print(sae.decoder.stored_inputs.shape)
# print(sae.decoder.stored_inputs)

# %%
next(cnn_model.parameters()).device
# Out:
# device(type='cuda', index=0)

# %%
cnn_model(next(iter(reference_train_loader))[0][:1].to(DEVICE))
# Out:
# tensor([[-18.0225,  -9.8141, -34.3493,  10.0203, -28.7933,  24.0919, -14.4446,
#          -23.1498, -10.0285,  -1.8420]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)

# %%
optimized_images_dict = {}
for name, module in cnn_model.named_children():
    if hasattr(module, 'out_features'):
        out = torch.arange(module.out_features)
    elif hasattr(module, 'out_channels'):
        out = torch.arange(module.out_channels)
        

    optimized_images_dict[name] = optim_inputs_for_neurons_in_layer(model=cnn_model, 
                                                             layer=cnn_model.fc2,
                                                             mode='activations',
                                                             neuron_indices=out,
                                                             alpha=2.0,
                                                             image_sparsity=0,
                                                             im_init='random', 
                                                             num_steps=1000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[93], line 6
#       1 optimized_images_dict = {}
#       2 for name, module in cnn_model.named_children():
#       3     optimized_images_dict[name] = optim_inputs_for_neurons_in_layer(model=cnn_model,
#       4                                                              layer=cnn_model.fc2,
#       5                                                              mode='activations',
# ----> 6                                                              neuron_indices=torch.arange(module.out_features),
#       7                                                              alpha=2.0,
#       8                                                              image_sparsity=0,
#       9                                                              im_init='random',
#      10                                                              num_steps=1000)
#
# File c:\Users\Comp\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1729, in Module.__getattr__(self, name)
#    1727     if name in modules:
#    1728         return modules[name]
# -> 1729 raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#
# AttributeError: 'Conv2d' object has no attribute 'out_features'

# %%
vals, indices = cnn_model.fc2.stored_activations.detach().cpu().topk(5)
well_trained = []
for idx, topk_indices in enumerate(indices):
    if idx in topk_indices:
        plusik = "\U0001F60D"
        well_trained.append(idx)
    else:
        plusik = ''
    
    print(f"{idx}: {topk_indices.tolist()} ~ {vals[idx].numpy()}" + plusik)

print(f"{len(well_trained)} well trained images.")
# Out:
# 0: [5, 9, 3, 6, 0] ~ [166.0638    62.76497   -9.334219 -31.44357  -74.079834]😍
# 1: [5, 1, 6, 3, 8] ~ [169.3997     -2.7886407 -33.50524   -34.396904  -92.96539  ]😍
# 2: [8, 2, 9, 3, 4] ~ [ 209.75314    124.902466     3.1778417  -26.901375  -133.62471  ]😍
# 3: [3, 5, 9, 1, 6] ~ [ 251.6993    147.61642    24.546257 -128.36813  -168.29762 ]😍
# 4: [4, 9, 8, 1, 2] ~ [ 413.88394   -49.051567  -54.91944   -68.67395  -107.1985  ]😍
# 5: [5, 3, 9, 6, 8] ~ [ 317.7447     61.14324    11.246777 -144.58035  -146.98882 ]😍
# 6: [6, 5, 8, 0, 9] ~ [237.3379    31.729609 -83.01339  -85.25248  -94.71195 ]😍
# 7: [9, 3, 7, 4, 5] ~ [222.74167    22.043253   21.062344    1.6135852 -61.088665 ]😍
# 8: [8, 5, 3, 9, 4] ~ [ 321.84576    59.07546   -62.158924  -77.72677  -159.0295  ]😍
# 9: [9, 5, 3, 8, 4] ~ [ 216.19427    82.333275   27.983469 -108.15976  -145.5993  ]😍
# 10 well trained images.

# %%
optimized_images_cnn_fc2 = optim_inputs_for_neurons_in_layer(model=nn.Sequential(cnn_model, sae), 
                                                             layer=sae.decoder,
                                                             mode='inputs',
                                                             neuron_indices=torch.arange(20),
                                                             alpha=2.0,
                                                             image_sparsity=0,
                                                             im_init='random', 
                                                             num_steps=100000)
# Out:
# Initial activations: None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 optimized_images_cnn_fc2 = optim_inputs_for_neurons_in_layer(model=nn.Sequential(cnn_model, sae),
#       2                                                              layer=sae.decoder,
#       3                                                              mode='inputs',
#       4                                                              neuron_indices=torch.arange(20),
#       5                                                              alpha=2.0,
#       6                                                              image_sparsity=0,
#       7                                                              im_init='random',
#       8                                                              num_steps=100000)
#
# Cell In[39], line 39, in optim_inputs_for_neurons_in_layer(model, layer, mode, neuron_indices, im_init, alpha, image_sparsity, num_steps, device)
#      36 activations_to_optimize_for = get_activations()
#      37 print(f"Initial activations: {get_activations()}")
# ---> 39 if max(neuron_indices) > activations_to_optimize_for.shape[-1]:
#      40     print("neuron_indices out of range.")
#      42 # Optimization loop
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
plt.figure(figsize=(12, 6))

activations_to_vis = cnn_model.fc2.stored_activations[3].flatten().detach()
print(activations_to_vis)
# Set up the positions and bar width
bar_width = 0.4
indices = torch.arange(len(activations_to_vis))



# Plot the original cnn activations
plt.bar(indices, activations_to_vis.cpu(), width=bar_width, color='darkmagenta', alpha=0.7, label='Values')

# Plot the reconstructed cnn activations with an offset and transparency

plt.xticks(indices)

plt.grid(True, which='both', linestyle='-', linewidth=0.5, alpha=0.5, axis='y')

# Adding labels, title, and legend
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Sparse representation')


# Adjust layout to prevent clipping
plt.tight_layout()
plt.show()
# Out:
# tensor([-391.1180,   -8.7949, -238.3698,  457.1006, -179.3947, -102.3991,
#         -196.2137,  -69.1933, -107.8641,  -44.8448], device='cuda:0')

# %%
batch = next(iter(reference_train_loader))
print(batch[0].shape)
visualize_ims(batch[0], 0)
cnn_model(batch[0][:1].to(DEVICE))
# Out:
# torch.Size([128, 1, 28, 28])
# tensor([[-18.0225,  -9.8141, -34.3493,  10.0203, -28.7933,  24.0919, -14.4446,
#          -23.1498, -10.0285,  -1.8420]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
